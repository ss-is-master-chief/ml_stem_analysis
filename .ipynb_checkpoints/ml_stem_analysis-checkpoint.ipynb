# %%
import numpy as np
import pandas as pd
import math 

data = pd.ExcelFile("2010-Federal-STEM-Education-Inventory Data-Set.xls")

data_frame = data.parse("Sheet1")

#
# Stage 1
#

FY2008 = list(data_frame['Unnamed: 5'])[1:]
FY2009 = list(data_frame['Unnamed: 6'])[1:]

def growth(year1,year2):
    if(year1!=0):
        per = ((float(year2) - float(year1))*100)/float(year1)
    else:
        per = (float(year2) - float(year1))*100
    if(math.isnan(per)):
        per = float(0)
    if(per>0):
        tag = 1
    else:
        tag = 0
    return [per,tag]

compute = []

for i in range(0,len(FY2008)):
    result = growth(FY2008[i],FY2009[i])
    compute.append(result)
    
df = pd.DataFrame(compute)
df.columns = ["Growth(%)","Tag"]

# %%
import pandas as pd
df_net = pd.read_excel('https://query.data.world/s/wpnmn52h4pcuqf4keg3pvf6l6n756g')

# %%
print(data_frame['Unnamed: 8'].unique()[1:])
# Out:
# ['General STEM' 'Agency Mission Workforce' nan]

# %%
#
# Univariate Distribution Variables
#

un1 = list(data_frame['Unnamed: 1'])[1:]
un2 = list(data_frame['Unnamed: 2'])[1:]
FUNDING = list(data_frame['FUNDING'])[1:]
un8 = list(data_frame['Unnamed: 8'])[1:]
un9 = list(data_frame['Unnamed: 9'])[1:]
#PO = list(data_frame['Primary Objective'])[1:]
un73 = list(data_frame['Unnamed: 73'])[1:]
un74 = list(data_frame['Unnamed: 74'])[1:]
un88 = list(data_frame['Unnamed: 88'])[1:]
un89 = list(data_frame['Unnamed: 89'])[1:]
leg = list(data_frame['Legistative Action to Change Program?])[1:]
ptshp = list(data_frame['Partnerships'])[1:]
Eval = list(data_frame['Eval'])[1:]

# %%
print(data_frame)
# Out:
#                                                         PROGRAM  \
# Index Number                                    Investment Name
# PRG_0001      Centers for Ocean Sciences Education Excellence ~
# PRG_0002            Broadening Participation in Computing (BPC)
# PRG_0003      CISE Pathways to Revitalized Undergraduate Com...
# PRG_0004      Opportunities for Enhancing Diversity in the G...
# PRG_0005                                   Geoscience Education
# PRG_0006                Geoscience Teacher Training (GEO-Teach)
# PRG_0007      Global Learning and Observations to Benefit th...
# PRG_0008            Graduate Research Fellowship Program (GRFP)
# PRG_0009      Integrative Graduate Education and Research Tr...
# PRG_0010      Graduate Teaching Fellows in K-12 Education (G...
# PRG_0012      East Asia & Pacific Summer Institutes for U.S....
# PRG_0013      Undergraduate Research and Mentoring in the Bi...
# PRG_0014                 Advanced Technological Education (ATE)
# ...

# %%
print(list(data_frame.columns.values))
# Out:
# ['PROGRAM', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'FUNDING', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Primary Objective', 'Secondary Objective', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Primary Approaches', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Secondary Approaches', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Not An Approach', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Services and Products', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54', 'Audience or Beneficiary', 'Unnamed: 56', 'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60', 'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63
# ...

# %%
import collections as cl

print(cl.Counter(un1),"\n")
print(cl.Counter(un2),"\n")
print(cl.Counter(FUNDING),"\n")
print(cl.Counter(un8),"\n")
print(cl.Counter(un9),"\n")
#print(cl.Counter(PO),"\n")
print(cl.Counter(un73),"\n")
print(cl.Counter(un74),"\n")
print(cl.Counter(un88),"\n")
print(cl.Counter(un89),"\n")
print(cl.Counter(leg),"\n")
print(cl.Counter(ptshp),"\n")
print(cl.Counter(Eval),"\n")
# Out:
# Counter({'NASA': 62, 'National Science Foundation': 40, 'Health & Human Services': 36, 'Energy': 25, 'Commerce': 19, 'Agriculture': 17, 'Defense': 16, 'Education': 15, 'Environmental Protection Agency': 8, 'Transportation': 5, 'Nuclear Regulatory Commission': 4, 'Homeland Security': 4, 'Interior': 1, nan: 1})
#
# ...

# %%
import matplotlib.pyplot as plt
from itertools import cycle, islice
import pylab as pl

# %%
# Univariate Distribution Plot 1
# Agency

print(cl.Counter(un1),"\n")

df = data_frame['Unnamed: 1'][1:]
my_colors = list(islice(cycle(['b', 'r', 'g', 'y', 'k']), None, len(df)))
df.value_counts().plot(kind='bar', stacked=True, color=my_colors)
pl.suptitle(r"Number of Funding Events per Agency")
plt.show()
# Out:
# Counter({'NASA': 62, 'National Science Foundation': 40, 'Health & Human Services': 36, 'Energy': 25, 'Commerce': 19, 'Agriculture': 17, 'Defense': 16, 'Education': 15, 'Environmental Protection Agency': 8, 'Transportation': 5, 'Nuclear Regulatory Commission': 4, 'Homeland Security': 4, 'Interior': 1, nan: 1})

# %%
# Univariate Distribution Plot 2
# Sub-Agency

print(cl.Counter(un2),"\n")

df = data_frame['Unnamed: 2'][1:]
my_colors = list(islice(cycle(['b', 'r', 'g', 'y', 'k']), None, len(df)))
df.value_counts().plot(kind='bar', stacked=True, color=my_colors,figsize=(22, 10))
pl.suptitle(r"Number of Funding Events per Sub-Agency")
plt.show()
# Out:
# Counter({'Directorate for Education and Human Resources (EHR)': 23, 'Science Mission Directorate (SMD)': 22, 'Education Office': 20, 'NOAA': 17, nan: 16, 'NIFA': 16, 'Office of Postsecondary Education (OPE)': 10, 'National Institute of General Medical Sciences (NIGMS)': 8, 'Office of Science, Office of Fusion Energy Sciences': 7, 'Office of Science, Office of Workforce Development for Teachers and Scientists': 7, 'Directorate for Geosciences (GEO)': 5, 'Office of Intramural Training and Education': 5, 'ESMD': 4, 'Center GRC': 4, 'Office Research and Development (ORD)': 4, 'National Heart, Lung, and Blood Institute (NHLBI)': 4, 'S&T Office of University Programs': 4, 'Directorate for Engineering (ENG)': 3, 'Center JSC': 3, 'Office of Environmental Education': 3, 'Institute of Education Sciences (IES)': 3, 'Office of Human Resources': 3, 'National Institutes of Health (NIH)': 3, 'National Cancer Institute (NCI)': 3, 'National Institute on Drug Abuse (NIDA)': 3, 'Federal Highway Adminis
# ...

# %%
# Univariate Distribution Plot 3
# Establishments

print(cl.Counter(FUNDING),"\n")

df = data_frame['FUNDING'][1:]
my_colors = list(islice(cycle(['b', 'r', 'g', 'y', 'k']), None, len(df)))
df.value_counts().plot(kind='bar', stacked=True, color=my_colors,figsize=(22, 10))
pl.suptitle("Number of establishments")
plt.show()
# Out:
# Counter({2008: 21, 2010: 14, 2001: 14, 2006: 14, 2009: 13, 2002: 12, 2007: 12, nan: 12, 2005: 11, 2003: 10, 1993: 9, 1999: 9, 1998: 8, 2004: 7, 1994: 7, 1991: 6, 1997: 6, 1995: 6, 2000: 5, 1990: 5, 1983: 4, 1992: 4, 1986: 4, 1987: 3, 1980: 3, 1972: 3, '2002': 2, '2006': 2, '1999': 2, 1989: 2, 1982: 2, 1976: 2, 1985: 2, 1988: 2, 1975: 2, '2007': 1, '1995': 1, '1952': 1, '1997': 1, '2004': 1, '2008': 1, 1961: 1, 1958: 1, 1978: 1, 1984: 1, 1977: 1, 1914: 1, 1968: 1})

# %%
# Univariate Distribution Plot 4
# Mission-specific or General STEM?

print(cl.Counter(un8),"\n")

df = data_frame['Unnamed: 8'][1:]
my_colors = list(islice(cycle(['b', 'r']), None, len(df)))
df.value_counts().plot(kind='bar', stacked=True, color=my_colors,figsize=(4,4))
pl.suptitle("Mission-specific or General STEM?")
plt.show()
# Out:
# Counter({'General STEM': 139, 'Agency Mission Workforce': 113, nan: 1})

# %%
# Univariate Distribution Plot 5
# Agency or Mission-Related Workforce Needs?

print(cl.Counter(un9),"\n")

df = data_frame['Unnamed: 9'][1:]
my_colors = list(islice(cycle(['b', 'r', 'g', 'y', 'k']), None, len(df)))
df.value_counts().plot(kind='bar', stacked=True, color=my_colors,figsize=(4,4))
pl.suptitle("Agency or Mission-Related Workforce Needs?")
plt.show()
# Out:
# Counter({nan: 143, 'Mission-related': 104, 'Agency workforce': 6})

# %%
# Univariate Distribution Plot 6
# Establishments

print(cl.Counter(un89),"\n")

df = data_frame['Unnamed: 89'][1:]
my_colors = list(islice(cycle(['b', 'r', 'g', 'y', 'k']), None, len(df)))
df.value_counts().plot(kind='bar', stacked=True, color=my_colors)
pl.suptitle("This is Figure title")
plt.show()
# Out:
# Counter({nan: 233, 'Informal STEM education leaders/program developers Policy makers': 19, 'Informal STEM education leaders/program developers': 1})

# %%
# Univariate Plot 7
# Legislation required to shift focus?

print(cl.Counter(leg),"\n")

df = data_frame['Legistative Action to Change Program?'][1:]
my_colors = list(islice(cycle(['b', 'r', 'g', 'y', 'k']), None, len(df)))
df.value_counts().plot.pie(figsize=(10,10))
pl.suptitle("Legislation required to shift focus?")
plt.show()
# Out:
# Counter({'No': 119, 'Yes': 76, "Don't know": 56, nan: 2})

# %%
# Univariate Distribution Plot 8
# Investment Partnerships

print(cl.Counter(ptshp),"\n")

df = data_frame['Partnerships'][1:]
my_colors = list(islice(cycle(['b', 'r', 'g', 'y', 'k']), None, len(df)))
df.value_counts().plot.pie(figsize=(10,10))
pl.suptitle("Investment Partnerships")
plt.show()
# Out:
# Counter({nan: 114, 'Encouraged': 61, 'No': 45, 'Required': 22, 'Mixed': 11})

# %%
# Univariate Distribution Plot 9
# Evaluated since 2005?

print(cl.Counter(Eval),"\n")

df = data_frame['Eval'][1:]
my_colors = list(islice(cycle(['b', 'r', 'g', 'y', 'k']), None, len(df)))
df.value_counts().plot.pie(figsize=(10,10))
pl.suptitle("Evaluated since 2005?")
plt.show()
# Out:
# Counter({'YES': 119, nan: 114, 'NO': 20})
